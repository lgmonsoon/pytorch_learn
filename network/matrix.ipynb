# %%
import numpy as np

A = np.array([[1, 2], [3, 4]])
A.shape
# Out:
# (2, 2)

# %%
B = np.array([[5, 6], [7, 8]])
B.shape
# Out:
# (2, 2)

# %%
np.dot(A, B)
# Out:
# array([[19, 22],
#        [43, 50]])

# %%
C = np.array([[1, 2], [3, 4], [5, 6]])
D = np.array([[1, 2, 3], [4, 5, 6]])

np.dot(C, D)
# Out:
# array([[ 9, 12, 15],
#        [19, 26, 33],
#        [29, 40, 51]])

# %%
print(np.dot(C, D))
# Out:
# [[ 9 12 15]
#  [19 26 33]
#  [29 40 51]]
