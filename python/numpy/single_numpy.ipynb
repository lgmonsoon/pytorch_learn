# %%
import numpy as np

# %%
x = np.array([1., 2, 3])
print(x)
type(x)
# Out:
# [1. 2. 3.]
# numpy.ndarray

# %%
print(type(x))
# Out:
# <class 'numpy.ndarray'>

# %%
x = np.array([1., 2, 3])
y = np.array([2., 55, 61])
print(x + y)
print(x - y)
print(x * y)
print(x / y)
# Out:
# [ 3. 57. 64.]
# [ -1. -53. -58.]
# [  2. 110. 183.]
# [0.5        0.03636364 0.04918033]

# %%
x = np.array([1, 2, 3])
x / 2.
# Out:
# array([0.5, 1. , 1.5])
