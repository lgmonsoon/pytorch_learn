# %%
import numpy as np

# %%
A = np.array([[1, 2], [3, 4]])
B = np.array([10, 20])
A * B
# Out:
# array([[10, 40],
#        [30, 80]])

# %%
X = np.array([[51, 55], [14, 19], [0, 4]])
print(X)
# Out:
# [[51 55]
#  [14 19]
#  [ 0  4]]

# %%
X[0]
# Out:
# array([51, 55])

# %%
X[0][1]
# Out:
# 55

# %%
## loop
for row in X:
    print(row)
# Out:
# [51 55]
# [14 19]
# [0 4]

# %%
X.shape
# Out:
# (3, 2)

# %%
## flatten
X = X.flatten()
print(X)
# Out:
# [51 55 14 19  0  4]

# %%
X[np.array([0, 2, 4])]
# Out:
# array([51, 14,  0])

# %%
X.dtype
# Out:
# dtype('int64')

# %%
X > 15
# Out:
# array([ True,  True, False,  True, False, False])

# %%
X[X > 15]
# Out:
# array([51, 55, 19])
