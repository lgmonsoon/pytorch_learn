# %%
a = [1, 2, 3, 4, 5]
print(a)
# Out:
# [1, 2, 3, 4, 5]

# %%
len(a)
# Out:
# 5

# %%
a[1]
# Out:
# 2

# %%
a[2]
# Out:
# 3

# %%
a[1] = 9
a[1]
# Out:
# 9

# %%
print(a)
# Out:
# [1, 9, 3, 4, 5]

# %%
print(a[1: -1])
# Out:
# [9, 3, 4]
