# %%
hungry = True
if hungry:
    print("want eat")
# Out:
# want eat

# %%
hungry = False
if hungry:
    print("want eat")
elif not hungry:
    print("want not eat")
else:
    print("error")
# Out:
# want not eat
